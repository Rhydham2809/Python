# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2101CS405</b></center>
# <center><b><h1>Lab - 9</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# # A

# %% [markdown]
# ### 01) WAP to handle divide by zero exception.

# %%
money = 2000
try:
  answer = money/0
except ZeroDivisionError as e:
  print(e.args[0])
# Out:
# division by zero

# %% [markdown]
# ### 02)  Write a Python program that inputs a number and generates an error message if it is not a number.

# %%
try:
  number = int(input("Please enter a number : "))
except ValueError as e:
  print(e.args[0])
# Out:
# Please enter a number : qwe
# invalid literal for int() with base 10: 'qwe'

# %% [markdown]
# ### 03) WAP to handle file not found Exception

# %%
try:
  file = open("rhydham.txt","r")
except FileNotFoundError as e:
  print(e.args)
# Out:
# (2, 'No such file or directory')

# %% [markdown]
# ### 04) WAP to handle type Exception.

# %%
try:
  sum = "string" + 2
except TypeError as e:
  print(e.args[0])
# Out:
# can only concatenate str (not "int") to str

# %% [markdown]
# ### 05) WAP to demonstrate valueError and indexError with example.

# %%
L=[1,2,3]
# try:
#   print(L[4])
# except IndexError as e:
#   print(e.args[0])
try:
  number = int(input("Please enter a number : "))
except ValueError as e:
  print(e.args[0])
# Out:
# Please enter a number : ioj
# invalid literal for int() with base 10: 'ioj'

# %% [markdown]
# ### 06) WAP to domonstrate else  and finally block.

# %%
try:
  answer = 1000/0
except:
  print("Error")  
else:
  print("No Error")  
finally:
  print("Ok")
# Out:
# Error
# Ok

# %% [markdown]
# ### 07) Create a short program that prompts the user for a list of grades separated by commas. Split the string into individual grades and use a list comprehension to convert each string to an integer. You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
try:
  a = input("Enter the grades comma seperated : ")
  L = a.split(",")
  converted = [int(i) for i in L]
except ValueError as e :
  print(e.args)
finally:  
  print(L)
  print(converted)
# Out:
# Enter the grades comma seperated : asd,85,96
# ("invalid literal for int() with base 10: 'asd'",)
# ['asd', '85', '96']
# [51, 74, 96, 56]

# %% [markdown]
# # B

# %% [markdown]
# ### 01) WAP to Raising User Generated Exception.

# %%
a = int(input("Please enter your age : "))
try:
  if(a<0):
    raise ValueError
except ValueError:
  print("Age cannot be negative")
else:
  print("Submitted successfully")
# Out:
# Please enter your age : -90
# Age cannot be negative

# %% [markdown]
# ### 02) WAP to raise your custom Exception.

# %%
class DivisibleByFiveError(Exception):

    "The number divided by Zero is an exception here"

    def __init__(self,arg): 
      self.arg = arg

try:
  answer = 125//5
  raise DivisibleByFiveError("Not divisible by 5 is exception here")
except DivisibleByFiveError as e:
  print(e.arg)
# Out:
# Not divisible by 5 is exception here

# %%
# More examples of Raising User Generated Exception

# 1.Passwords crietria
integerNumber = 0
character = 0 
username = input("Please enter username : ")
try:
  password = input("Please enter password : ")
  for i in password:
      try:
        int(i)
      except:
         str(i) 
         character = 1 + character
      else:
         integerNumber = 1 + integerNumber        
  if(len(password)<8):
    raise ValueError("Password should be 8 characters or more")
  elif(integerNumber==0 or character==0):
    if(integerNumber == 0):
      raise ValueError("There should be an integer in password")
    else:
      raise ValueError("There should be a in password")
except ValueError as e:
  print(e.args[0])
# Out:
# Please enter username : rhydham
# Please enter password : 23redfs
# Password should be 8 characters or more

# %%
integerNumber = 0
character = 0 
Capitalcharcater = 0
count = 0
password = input("Please enter password : ")
for i in password:
      if(count==0):
        try:
          str(i)
        except:
            raise ValueError("First character should be character")
      try:
        int(i)
      except:   
         str(i) 
         character = 1 + character
         if(ord(i)<=90 and ord(i)>=65):
           Capitalcharcater = 1 + Capitalcharcater
      else:
         integerNumber = 1 + integerNumber 
print(integerNumber)
print(Capitalcharcater)
print(character)
# Out:
# Please enter password : Aygw123
# 3
# 1
# 4
