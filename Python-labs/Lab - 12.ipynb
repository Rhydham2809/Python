# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2101CS405</b></center>
# <center><b><h1>Lab - 12</b></center>
# <pre>

# %% [markdown]
# # OOP

# %% [markdown]
# ### 01) Write a Program to create a class by name Students, and initialize attributes like name, age, and grade while creating an object.

# %%
class Students:
  def information(self,name,age,grade):
    self.name  = name
    self.age   = age
    self.grade = grade

  def display(self):
    print(f"Name : {self.name}\nAge : {self.age}\nGrade : {self.grade}")  

s1 = Students()
s1.information('Rhydham',19,'AA')    
s1.display()
# Out:
# Name : Rhydham
# Age : 19
# Grade : AA

# %% [markdown]
# ### 02) Create a class named Bank_Account with Account_No, User_Name, Email,Account_Type and Account_Balance data members. Also create a method GetAccountDetails() and DisplayAccountDetails(). Create main method to demonstrate the Bank_Account class.

# %%
class Bank_Account:
  Account_No = 0
  User_Name  = ''
  Email = ''
  Account_Type = ''
  Account_Balance = 0

  def GetAccountDetails(self):
    self.Account_No      = int(input("Enter Account NO : "))
    self.User_Name       = input("Enter username : ")
    self.Email           = input("Enter Email : ")
    self.Account_Type    = input("Enter Account type : ")
    self.Account_Balance = input("Enter Account Balance : ")

  def DisplayAccountDetails(self):
    print(f"Account No : {self.Account_No}\nUsername : {self.User_Name}\nEmail : {self.Email}\nAccount type : {self.Account_Type}\nAccount balance : {self.Account_Balance}")


b1 = Bank_Account()
b1.GetAccountDetails()
print("======================")
b1.DisplayAccountDetails()
# Out:
# Enter Account NO : 1234
# Enter username : qwe
# Enter Email : qwe@gmail.com
# Enter Account type : erty
# Enter Account Balance : 12346678
# ======================
# Account No : 1234
# Username : qwe
# Email : qwe@gmail.com
# Account type : erty
# Account balance : 12346678

# %% [markdown]
# ### 03) WAP to create Circle class with area and perimeter function to find area and perimeter of circle.

# %%
class Circle:

    def __init__(self,r):
      self.r = r 

    def area(self):
      print(f"Area : {3.14*self.r*self.r}")

    def perimeter(self):
      print(f"Perimeter : {2*3.14*self.r}") 
         

c1 = Circle(4)
c1.area()
c1.perimeter()
# Out:
# Area : 50.24
# Perimeter : 25.12

# %% [markdown]
# ### 04) Create a class for employees that includes attributes such as name, age, salary, and methods to update and display employee information.

# %%
class Employees:
  name = ''
  age  = 0
  salary = 0

  def __init__(self,name,age,salary):
    self.name   = name
    self.age    = age
    self.salary = salary

  def update(self):
    self.age    = int(input("Please enter age : "))
    self.salary = int(input("Please enter salary : "))

  def display(self):
    print(f"Name : {self.name}\nAge : {self.age}\nSalary : {self.salary}") 


e1 = Employees("abc",23,12000)
print("================Displaying before update==============")
e1.display()
print("==============Updating===========")
e1.update()
print("================Displaying after update=============")
e1.display()
# Out:
# ================Displaying before update==============
# Name : abc
# Age : 23
# Salary : 12000
# ==============Updating===========
# Please enter age : 45
# Please enter salary : 56789
# ================Displaying after update=============
# Name : abc
# Age : 45
# Salary : 56789

# %% [markdown]
# ### 05) Create a bank account class with methods to deposit, withdraw, and check balance.

# %%
class Bank_Account:
  Amount = 0
  def deposit(self):
    a = int(input("Please enter amount to be deposited : "))
    self.Amount = self.Amount + a

  def withdraw(self):
    withdraw = int(input("Please enter amount to be withdrawed : "))
    if(self.Amount<withdraw):
      print("Less Amount")
    else:
      self.Amount = self.Amount-withdraw

  def checkBalance(self):
    print(f"The current balance is : {self.Amount}")  

b1 = Bank_Account()
b1.checkBalance()
b1.deposit()
b1.withdraw()
b1.checkBalance()
b1.deposit()
b1.checkBalance()  
b1.withdraw()
# Out:
# The current balance is : 0
# Please enter amount to be deposited : 5000
# Please enter amount to be withdrawed : 1000
# The current balance is : 4000
# Please enter amount to be deposited : 0
# The current balance is : 4000
# Please enter amount to be withdrawed : 6000
# Less Amount

# %% [markdown]
# ### 06) Create a class for managing inventory that includes attributes such as item name, price, quantity, and methods to add, remove, and update items.

# %%
lists = []
class Inventory:
  name = ''
  price = 0
  quantity = 0

  def add(self):
    map = {}
    map['name'] = input("Please enter name of product : ")
    map['price'] = int(input("Please enter price : "))
    map['quantity'] = int(input("Please enter quantity : "))
    lists.append(map)

  def remove(self,name):
    for i in lists:
      if i['name'] == name:
        lists.remove(i)   

  def update(self,name):
    for i in lists:
      if i['name']==name:
        lists[lists.index(i)]['price'] = int(input("Please enter price : "))
        lists[lists.index(i)]['quantity'] = int(input("Please enter quantity : "))

i1 = Inventory()
i1.add()
i2 = Inventory()
i2.add()
i3 = Inventory()
i3.add()

deleteItemName = input("Input item you want to delete : ")
i1.remove(deleteItemName)
updateItemName = input("Input item you want to update : ")
i1.update(updateItemName)


print(lists)
# Out:
# Please enter name of product : a
# Please enter price : 12
# Please enter quantity : 12
# Please enter name of product : b
# Please enter price : 23
# Please enter quantity : 23
# Please enter name of product : c
# Please enter price : 3
# Please enter quantity : 34
# Input item you want to delete : b
# Input item you want to update : c
# Please enter price : 333
# Please enter quantity : 333
# [{'name': 'a', 'price': 12, 'quantity': 12}, {'name': 'c', 'price': 333, 'quantity': 333}]

# %% [markdown]
# ### 09) Create a Class with instance attributes

# %%
class ABC:
  def __init__(self,name):
    self.name = name
    print(name)

a = ABC("ABC")
# Out:
# ABC

# %% [markdown]
# ### 07)
# Create one class student_kit <br>
# Within the student_kit class create one class attribute principal name ( Mr ABC ) <br>
# Create one attendance method and take input as number of days. <br>
# While creating student take input their name . <br>
# Create one certificate for each student by taking input of number of days present in class. <br>

# %%
class Student_Kit:
  principal_Name = "Mr ABC"

  def __init__(self,name):
    self.name = name

  def attendence(self,days):
    self.days = days

  def certificate(self):
    print(f"This certificat is for {self.name} for being present {self.days} total days\n             By school principle {Student_Kit.principal_Name}")  

s1 = Student_Kit("A")
s2 = Student_Kit("B")

s1.attendence(200)
s2.attendence(230)

s1.certificate()
print("================XXXXX=================")
s2.certificate()
# Out:
# This certificat is for A for being present 200 total days
#              By school principle Mr ABC
# ================XXXXX=================
# This certificat is for B for being present 230 total days
#              By school principle Mr ABC

# %% [markdown]
# ### 08) Define Time class with hour and minute as data member. Also define addition method to add two time objects.

# %%
class Time:
  hour = 0
  min  = 0

  def __init__(self,hour,min):
    self.hour = hour
    self.min  = min

  def add(self,t1,t2):
    self.hour = t1.hour + t2.hour
    self.min  = t1.min  + t2.min
    print(f"{self.hour} : {self.min}")  

t1 = Time(2,3)
t2 = Time(3,4)
t3 = Time(0,0)
t3.add(t1,t2)
# Out:
# 5 : 7

# %% [markdown]
# ### 09) WAP to demonstrate inheritance in python.

# %%
#Simple inheritance 

class A:
  def method1(self):
    print("A")

class B(A):
  def method2(self):
    print("B") 

b = B()
b.method1()
b.method2()    

#Multiple inheritance

class A:
  def method1(self):
    print("A")

class C:
  def method3(self):
    print("C")    

class B(A,C):
  def method2(self):
    print("B") 

b = B()
b.method1()
b.method2()
b.method3() 

#Multilevel inheritance

class A:
  def method1(self):
    print("A")

class B(A):
  def method2(self):
    print("B")    

class C(B):
  def method3(self):
    print("C")    

c = C()
c.method1()
c.method2()
c.method3()

#Heirarchical inheritance

class A:
  def method1(self):
    print("A")

class B(A):
  def method2(self):
    print("B")    

class C(A):
  def method3(self):
    print("C")    


b = B()
b.method1()
b.method2()
c = C()
c.method1()
c.method3()
# Out:
# A
# B
# A
# C

# %% [markdown]
# ### 10) Create a child class Bus that will inherit all of the variables and methods of the Vehicle class
# class Vehicle:
#
#     def __init__(self, name, max_speed, mileage):
#         self.name = name
#         self.max_speed = max_speed
#         self.mileage = mileage
#
# Create a Bus object that will inherit all of the variables and methods of the parent Vehicle class and display it.

# %%
class Vehicle:
  def __init__(self, name, max_speed, mileage):
    self.name = name
    self.max_speed = max_speed
    self.mileage = mileage

class Bus(Vehicle):
  
  def Display(self):
    print(self.name)
    print(self.max_speed)
    print(self.mileage)

b = Bus("Bus",90,56)  
b.Display()
# Out:
# Bus
# 90
# 56

# %% [markdown]
# ### 11)  Create a class hierarchy for different types of animals, with a parent Animal class and child classes for specific animals like Cat, Dog, and Bird.

# %%
class Animals:
  legs = 0
  habitat = ''
  def information(self):
    self.legs = int(input("Please enter number of legs : "))
    self.habitat = input("Please enter habitat : ")

class Cat(Animals):
  def __init__(self):
    print("Cat")
    super().information()
    print(f"Name : Cat\nLegs : {self.legs}\nHabitat : {self.habitat}")
    
class Dog(Animals):
  def __init__(self):
    print("Dog")
    super().information()
    print(f"Name : Dog\nLegs : {self.legs}\nHabitat : {self.habitat}")

class Bird(Animals):
  def __init__(self):
    print("Bird")
    super().information()
    print(f"Name : Bird\nLegs : {self.legs}\nHabitat : {self.habitat}")       

c = Cat()
d = Dog()
b = Bird()
# Out:
# Cat
# Please enter number of legs : 4
# Please enter habitat : all
# Name : Cat
# Legs : 4
# Habitat : all
# Dog
# Please enter number of legs : 4
# Please enter habitat : all
# Name : Dog
# Legs : 4
# Habitat : all
# Bird
# Please enter number of legs : 2
# Please enter habitat : all
# Name : Bird
# Legs : 2
# Habitat : all

# %% [markdown]
# ### 12) Create a class hierarchy for different types of vehicles, with a parent Vehicle class and child classes for specific vehicles like Car, Truck, and Motorcycle.

# %%
class Vehicles:
  max_speed = 0
  milage = 0
  def information(self):
    self.max_speed = int(input("Please enter number of max speed : "))
    self.milage = int(input("Please enter number of milage : "))

class Car(Vehicles):
  def __init__(self):
    super().information()
    print(f"Name : Car\nMax speed : {self.max_speed}\nMilage : {self.milage}")
    
class Truck(Vehicles):
  def __init__(self):
    super().information()
    print(f"Name : Truck\nMax speed : {self.max_speed}\nMilage : {self.milage}")

class Motorcycle(Vehicles):
  def __init__(self):
    super().information()
    print(f"Name : Motorcycle\nMax speed : {self.max_speed}\nMilage : {self.milage}")       

c = Car()
t = Truck()
m = Motorcycle()
# Out:
# Please enter number of max speed : 34
# Please enter number of milage : 45
# Name : Car
# Max speed : 34
# Milage : 45
# Please enter number of max speed : 56
# Please enter number of milage : 56
# Name : Truck
# Max speed : 56
# Milage : 56
# Please enter number of max speed : 78
# Please enter number of milage : 78
# Name : Motorcycle
# Max speed : 78
# Milage : 78

# %% [markdown]
# ### 13)  Create a class hierarchy for different types of bank accounts, with a parent Account class and child classes for specific account types like Checking, Savings, and Credit.

# %%
class Account:
  Account_no  = ''
  customerID  = ''
  Credit = 2000
  Savings = 10000
  Balance = 0

  def __init__(self):
    self.Account_no  = input("Please enter account number : ")
    self.customerID  = input("Please enter CustomerID : ")
    self.Balance  = input("Please enter amount to deposit : ")

class Checkings(Account):
  def __init__(self):
    super().__init__()
    print(f"Balance = {self.Balance}")    

class Savings(Account):
  def __init__(self):
    print(f"Savings = {self.Savings}")    

class Credit(Account):
  def __init__(self):
    print(f"Credit = {self.Credit}")    

c1 = Checkings()
s1 = Savings() 
ci = Credit()
# Out:
# Please enter account number : 123
# Please enter CustomerID : 12
# Please enter amount to deposit : 12345
# Balance = 12345
# Savings = 10000
# Credit = 2000

# %% [markdown]
# ### 14) Create a Shape class with a draw method that is not implemented. Create three child classes Rectangle, Circle, and Triangle that implement the draw method with their respective drawing behaviors. Create a list of Shape objects that includes one instance of each child class, and then iterate through the list and call the draw method on each object.

# %%
from abc import ABC,abstractmethod

class Shape:
  @abstractmethod
  def draw(self):
    pass

class Rectangle(Shape):
  def draw(self):
    print("Rectangle")

class Circle(Shape):
  def draw(self):
    print("Circle")

class Triangle(Shape):
  def draw(self):
    print("Triangle")        

r1 = Rectangle()
c1 = Circle()
t1 = Triangle()

L1 = [r1,c1,t1]

for i in L1:
  i.draw()
# Out:
# Rectangle
# Circle
# Triangle

# %% [markdown]
# ### 15) Create a Person class with a constructor that takes two arguments name and age. Create a child class Employee that inherits from Person and adds a new attribute salary. Override the __init__ method in Employee to call the parent class's __init__ method using the super keyword, and then initialize the salary attribute.

# %%
class Person:

  name = ''
  age = 0

  def __init__(self):
    self.name = input("Please enter name : ") 
    self.age  = int(input("Please enter age : "))

class Employee(Person):
  salary = 0
  def __init__(self):
    super().__init__()
    self.salary = int(input("Please enter salary : "))

  def display(self):
    print(f"Name : {self.name}\nAge : {self.age}\nSalary : {self.salary}")  

  
e1 = Employee()
e2 = Employee()
e1.display()
e2.display()
# Out:
# Please enter name : A
# Please enter age : 23
# Please enter salary : 12345
# Please enter name : B
# Please enter age : 34
# Please enter salary : 567890
# Name : A
# Age : 23
# Salary : 12345
# Name : B
# Age : 34
# Salary : 567890
